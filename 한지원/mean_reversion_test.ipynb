# %% [markdown]
# # 1. 시계열 데이터 분석 : Random walk의 생성과 정상성 판단, ARIMA 모델

# %% [markdown]
# 먼저, 코딩에 필요한 함수가 들어가 있는 기본 라이브러리를 불러와 줍니다.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 코드가 잘 돌아가는지 확인하기 위해, Random walk data를 생성하고, 모양을 plot으로 그려 확인해 봅시다!

# %%
#무작위 보행 생성!
np.random.seed(42)
n = 10000
mean = 0
std_dev = 1
mean_reversion_speed = 0.1
data = np.zeros(n)
data[0] = np.random.randn()

for t in range(1, n):
    shock = np.random.randn() * std_dev
    data[t] = data[t-1] + mean_reversion_speed * (mean - data[t-1]) + shock
data+=10


#무작위 보행 그래프 그리기
pd.DataFrame(data).plot()
# Out:
# <Axes: >

# %% [markdown]
# 시계열 데이터를 분석하기 전, 분석이 가능한 상태인지 확인하는 정상성 검정을 시행해 봅시다.

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# 정상성 검정에는 주로 adf 검정을 많이 쓰고, 이 검정은 adfuller 라이브러리를 통해 쉽게 진행할 수 있습니다.

# %%
def adftest(data):
    #adf 검정!
    result = adfuller(data)

    print('정상성이 있는지 판단 : ')
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))
    return key

# %% [markdown]
# 만들어둔 data로 검정을 실시해 볼까요?

# %%
key = adftest(data)
# Out:
# 정상성이 있는지 판단 :
# ADF Statistic: -23.869146
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# p-value가 0.05 이하이므로, 해당 데이터는 정상성을 갖고 있다 말할 수 있습니다.
# 이제 이 데이터로 시계열 데이터 분석을 진행할 수 있습니다!

# %%
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# 기본 시계열 예측 모형인 ARIMA 모형은 statsmodel의 ARIMA 라이브러리를 사용해 쉽게 분석할 수 있습니다.

# %%
def ARIMA_model(data):
    #델타yt의 경우와 그냥 yt의 경우에 감마의 값에 따라 평균회귀 가능성이 어떻게 달라지는지 조심하세요
    model = ARIMA(data, order=(1, 0, 0))
    model_fit = model.fit()
    print(f'λ 값의 유도(델타yt가 아닌 그냥 yt임 주의!!) : { model_fit.params[1] }')
    half = -np.log(2)/(model_fit.params[1]-1)
    print(f'반감기 : {half}')

    display(model_fit.summary())
    return half

# %% [markdown]
# 만들어둔 데이터로 모델에 fitting 시켜 봅시다!

# %%
half=ARIMA_model(data)
# Out:
# λ 값의 유도(델타yt가 아닌 그냥 yt임 주의!!) : 0.8921572669821072
# 반감기 : 6.427388857485104
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood              -14222.642
# Date:                Tue, 02 Apr 2024   AIC                          28451.283
# Time:                        20:33:14   BIC                          28472.914
# Sample:                             0   HQIC                         28458.605
#                               - 10000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.9794      0.093    107.273      0.000       9.797      10.162
# ar.L1          0.8922      0.005    195.268      0.000       0.883       0.901
# sigma2         1.0065      0.014     71.183      0.000       0.979       1.034
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.43   Jarque-Bera (JB):                 0.30
# Prob(Q):                              0.51   Prob(JB):                         0.86
# Heteroskedasticity (H):               1.04   Skew:                             0.00
# Prob(H) (two-sided):                  0.25   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # 2. Random walk의 반감기를 측정하는 Hurst 지수 검정

# %% [markdown]
# 정상성 검정과 ARIMA 모델을 실습했다면, 이제 Hurst 지수 검정을 진행할 차례입니다.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 기본 라이브러리를 불러온 뒤, RS공식과 지수를 계산하는 함수를 제작해 봅시다!

# %%
#허스트 지수 유도를 위한 RS 공식(변동성) 함수
def RS_func(data):
    L = np.log10(data[1:] / data[:-1])
    Z = np.mean(L)
    C = np.cumsum(L-Z)
    R = max(C) - min(C)
    S = np.std(L)

    if R == 0 or S == 0:
        return 0

    return R / S

#허스트 지수 검정 계산  <- basic exponent
def hurst_func(data):
    min_window = 10
    max_window = len(data) - 1
    by_factor = np.log10(2.0)
    window_sizes = list(map(lambda x: int(10 ** x),np.arange(np.log10(min_window), np.log10(max_window), by_factor)))
    window_sizes.append(len(data))

    RS = []
    for w in window_sizes:
        rs = []
        for start in range(0, len(data), w):
            if (start + w) > len(data):
                break
            res = RS_func(data[start:start + w].astype(np.float64))
            if res != 0:
                rs.append(res)
        RS.append(np.mean(rs))

    lm1 = LinearRegression().fit(np.log10(window_sizes).reshape(-1, 1),np.log10(RS).reshape(-1, 1))
    hurst_exp = lm1.coef_[0][0]
    return hurst_exp

# %% [markdown]
# 허스트 검정 함수를 데이터로 실습해 볼까요?

# %%
hurst_func(data)
# Out:
# 0.25173651809405323

# %% [markdown]
# # 3. 백테스트를 위한 포지션 함수 생성

# %% [markdown]
# 백테스트를 통해 분석 결과를 확인해 봅시다.

# %%
# 백테스트를 위한 포지션 함수
def position(data,half):
    overall_mean = np.mean(data)
    overall_std = np.std(data)
    overall_mean, overall_std
    df = pd.DataFrame(data, columns=['price'])
    df['mean'] = overall_mean
    df['std'] = overall_std
    df['upper'] = overall_mean + 2*overall_std
    df['lower'] = overall_mean - 2*overall_std

    holding_period = half  # 가정한 보유 기간
    stop_loss_threshold = 0.2  # 손절 기준
    positions = []

    for i in range(1, len(df)):
        current_price = df.iloc[i]['price']
        previous_price = df.iloc[i-1]['price']
        upper_bound = df.iloc[i]['upper']
        lower_bound = df.iloc[i]['lower']

        if not positions or positions[-1]['exit_price'] is not None:
            if previous_price > upper_bound and current_price <= upper_bound:
                positions.append({'type': 'short', 'entry_price': current_price, 'entry_index': i, 'exit_price': None})
            elif previous_price < lower_bound and current_price >= lower_bound:
                positions.append({'type': 'long', 'entry_price': current_price,'entry_index': i,  'exit_price': None})

        if positions and positions[-1]['exit_price'] is None:
            position = positions[-1]
            elapsed_time = i - position['entry_index']
            loss = 0

            if position['type'] == 'long':
                loss = (current_price - position['entry_price']) / position['entry_price']
            else:
                loss = (position['entry_price'] - current_price) / position['entry_price']

            #손절,익절 공식 : 스탑로스컷 맞는지 확인 and 보유기간 넘는지 확인 and 평균 돌아왔는지
            if loss < -stop_loss_threshold or elapsed_time > holding_period or (position['type'] == 'long' and current_price >= overall_mean) or (position['type'] == 'short' and current_price <= overall_mean):
                position['exit_price'] = current_price
                position['pnl'] = loss
                position['elapsed_day']= elapsed_time

    positions_summary = [{'type': p['type'], 'entry_price': p['entry_price'], 'exit_price': p['exit_price'], 'pnl': p['pnl'],'entry_day':p['entry_index'],'elapsed_day':p['elapsed_day']} for p in positions if p['exit_price'] is not None]
    return positions_summary

# %% [markdown]
# 함수의 작동 확인을 위해, 데이터를 넣고 마지막 10개의 포지션을 출력해 봅시다.

# %%
positions = position(data,half)
positions[:-10]
# Out:
# [{'type': 'long',
#   'entry_price': 6.061423599876523,
#   'exit_price': 6.008350988634831,
#   'pnl': -0.00875579975020609,
#   'entry_day': 39,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.459573954862652,
#   'exit_price': 11.215357617532225,
#   'pnl': 0.16673754643768943,
#   'entry_day': 181,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.892150626037438,
#   'exit_price': 10.68268335232909,
#   'pnl': 0.23102738806279477,
#   'entry_day': 216,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.393735049373982,
#   'exit_price': 9.699017983089188,
#   'pnl': 0.2758541252805716,
#   'entry_day': 375,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.239813997532972,
#   'exit_price': 12.869384770287624,
#   'pnl': 0.09623926460575767,
#   'entry_day': 422,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.935972375761707,
#   'exit_price': 9.80811900359391,
#   'pnl': 0.23590639422462864,
#   'entry_day': 460,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.145110081855893,
#   'exit_price': 13.037949183846269,
#   'pnl': 0.8247373426694292,
#   'entry_day': 473,
#   'elapsed_day': 5},
#  {'type': 'long',
#   'entry_price': 5.703941815464117,
#   'exit_price': 4.961703012513389,
#   'pnl': -0.13012734473174728,
#   'entry_day': 527,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.692184971427297,
#   'exit_price': 6.396088024789599,
#   'pnl': -0.04424518268725429,
#   'entry_day': 538,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.28416403526661,
#   'exit_price': 11.690802074313456,
#   'pnl': 0.1199444659613596,
#   'entry_day': 626,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.594133212424547,
#   'exit_price': 10.295512198647057,
#   'pnl': 0.8404124120213595,
#   'entry_day': 647,
#   'elapsed_day': 4},
#  {'type': 'long',
#   'entry_price': 7.701827585811383,
#   'exit_price': 10.252145993334095,
#   'pnl': 0.33113158910763085,
#   'entry_day': 677,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 6.3086274680379635,
#   'exit_price': 9.102056424028552,
#   'pnl': 0.4427950406238472,
#   'entry_day': 753,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.861783323255098,
#   'exit_price': 11.185314030564905,
#   'pnl': 0.19308260923398204,
#   'entry_day': 823,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.350714820633863,
#   'exit_price': 17.256162631436244,
#   'pnl': -0.20246014551308938,
#   'entry_day': 887,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.96922272704811,
#   'exit_price': 13.043517402058473,
#   'pnl': 0.06626748982942532,
#   'entry_day': 901,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.104400111689277,
#   'exit_price': 14.152065961976996,
#   'pnl': -0.003379502134813639,
#   'entry_day': 910,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.237993153902405,
#   'exit_price': 8.68855072331844,
#   'pnl': 0.38976296522961545,
#   'entry_day': 968,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.181386683274344,
#   'exit_price': 8.631141344779284,
#   'pnl': 0.39631150533479975,
#   'entry_day': 979,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.108420069470313,
#   'exit_price': 12.869426656133022,
#   'pnl': 0.08781943032858726,
#   'entry_day': 1013,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.22574821022275,
#   'exit_price': 10.780660168935059,
#   'pnl': 0.24217271319423608,
#   'entry_day': 1027,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.932494203024262,
#   'exit_price': 15.32095222741281,
#   'pnl': -0.09965609919917726,
#   'entry_day': 1117,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.642511611652841,
#   'exit_price': 13.908968479968422,
#   'pnl': -0.01953136459770246,
#   'entry_day': 1125,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.051606697041747,
#   'exit_price': 12.817153217036399,
#   'pnl': 0.017963572259535564,
#   'entry_day': 1137,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.786764549322827,
#   'exit_price': 10.644254667182977,
#   'pnl': 0.22793671937294396,
#   'entry_day': 1237,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.458497962475062,
#   'exit_price': 4.923259041690507,
#   'pnl': -0.2377083541257652,
#   'entry_day': 1352,
#   'elapsed_day': 3},
#  {'type': 'long',
#   'entry_price': 5.788023825744622,
#   'exit_price': 8.137671073442641,
#   'pnl': 0.40594982302024996,
#   'entry_day': 1357,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.193352604956537,
#   'exit_price': 12.866474133020688,
#   'pnl': 0.09348590913414516,
#   'entry_day': 1388,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.35929355059353,
#   'exit_price': 15.392295305132965,
#   'pnl': -0.15217883691530315,
#   'entry_day': 1414,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.200092073230099,
#   'exit_price': 9.685389715321447,
#   'pnl': 0.26626347289171554,
#   'entry_day': 1423,
#   'elapsed_day': 2},
#  {'type': 'short',
#   'entry_price': 13.507225995193206,
#   'exit_price': 12.216837130307349,
#   'pnl': 0.09553322535249398,
#   'entry_day': 1455,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.066596241335585,
#   'exit_price': 14.383951756699142,
#   'pnl': -0.02256093157995023,
#   'entry_day': 1502,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.901361001081593,
#   'exit_price': 9.878350481648726,
#   'pnl': 0.28939688129240426,
#   'entry_day': 1528,
#   'elapsed_day': 6},
#  {'type': 'long',
#   'entry_price': 7.616181941874167,
#   'exit_price': 9.648403584676323,
#   'pnl': 0.2668294505451472,
#   'entry_day': 1541,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.1806140819937365,
#   'exit_price': 4.81148499035566,
#   'pnl': -0.22151991266156265,
#   'entry_day': 1592,
#   'elapsed_day': 3},
#  {'type': 'long',
#   'entry_price': 5.949490752325292,
#   'exit_price': 8.290485806121993,
#   'pnl': 0.3934782238096175,
#   'entry_day': 1596,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.947570730422228,
#   'exit_price': 14.49232560094001,
#   'pnl': -0.03905732984236248,
#   'entry_day': 1653,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.92502451385493,
#   'exit_price': 9.957031811306653,
#   'pnl': 0.28495409100359276,
#   'entry_day': 1661,
#   'elapsed_day': 6},
#  {'type': 'short',
#   'entry_price': 13.866518541752972,
#   'exit_price': 10.436383796631723,
#   'pnl': 0.24736812883442186,
#   'entry_day': 1708,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 12.622245723624372,
#   'exit_price': 12.561385561816717,
#   'pnl': 0.0048216587713663765,
#   'entry_day': 1763,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.229287952996135,
#   'exit_price': 10.234983506744603,
#   'pnl': 0.6430422841220284,
#   'entry_day': 1806,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.034905227248279,
#   'exit_price': 9.504172515590016,
#   'pnl': 0.32281890317734413,
#   'entry_day': 1996,
#   'elapsed_day': 6},
#  {'type': 'long',
#   'entry_price': 7.68538382713682,
#   'exit_price': 10.086604538089697,
#   'pnl': 0.3124399203686159,
#   'entry_day': 2026,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.333403878491179,
#   'exit_price': 14.453863481296642,
#   'pnl': -0.008404116972258445,
#   'entry_day': 2310,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.450175379220948,
#   'exit_price': 14.189882973318829,
#   'pnl': -0.05499613003118522,
#   'entry_day': 2318,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.845982332597525,
#   'exit_price': 10.142851342078123,
#   'pnl': 0.7350123152991783,
#   'entry_day': 2401,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 12.98109196676646,
#   'exit_price': 11.197453815311519,
#   'pnl': 0.1374027821404641,
#   'entry_day': 2529,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.644061569414092,
#   'exit_price': 10.898698568347948,
#   'pnl': 0.2012130322850805,
#   'entry_day': 2585,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.250792564239392,
#   'exit_price': 9.5776540708715,
#   'pnl': 0.532230348782487,
#   'entry_day': 2608,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.362391023059642,
#   'exit_price': 11.96556176628441,
#   'pnl': 0.16688232850136064,
#   'entry_day': 2636,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.910385798228997,
#   'exit_price': 10.685120685795082,
#   'pnl': 0.23186022006985169,
#   'entry_day': 2708,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.955869486470016,
#   'exit_price': 14.42160027671083,
#   'pnl': -0.033371678539436914,
#   'entry_day': 2728,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.644302467868297,
#   'exit_price': 14.678004134643661,
#   'pnl': -0.0757606824687216,
#   'entry_day': 2736,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 11.680643643484991,
#   'exit_price': 13.302490992498981,
#   'pnl': -0.13884914209488733,
#   'entry_day': 2744,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.002941079873468,
#   'exit_price': 6.912834801317219,
#   'pnl': 0.15157465471290787,
#   'entry_day': 2789,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.280345345678149,
#   'exit_price': 10.210808037370954,
#   'pnl': 0.6258354398293675,
#   'entry_day': 2799,
#   'elapsed_day': 3},
#  {'type': 'short',
#   'entry_price': 14.302941748474186,
#   'exit_price': 9.259984275246563,
#   'pnl': 0.35258183679351124,
#   'entry_day': 2840,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.946139498438759,
#   'exit_price': 4.712937940006912,
#   'pnl': -0.20739532914685935,
#   'entry_day': 2889,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 6.009851362637958,
#   'exit_price': 11.649332294926122,
#   'pnl': 0.9383727802899897,
#   'entry_day': 2892,
#   'elapsed_day': 3},
#  {'type': 'short',
#   'entry_price': 13.522203148160745,
#   'exit_price': 11.071635338886491,
#   'pnl': 0.1812254839262324,
#   'entry_day': 2936,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.818113570023801,
#   'exit_price': 7.261713890086153,
#   'pnl': 0.24812171551619372,
#   'entry_day': 3019,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.346184965513377,
#   'exit_price': 6.873669611386119,
#   'pnl': 0.08311838509895546,
#   'entry_day': 3032,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.029425077216668,
#   'exit_price': 4.520251606601061,
#   'pnl': -0.25030138882035485,
#   'entry_day': 3158,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.735049689812252,
#   'exit_price': 5.593605228996624,
#   'pnl': -0.024663162215820083,
#   'entry_day': 3168,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.1236927338207465,
#   'exit_price': 8.896207466537787,
#   'pnl': 0.4527520979954834,
#   'entry_day': 3178,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.099284630199449,
#   'exit_price': 13.019542134152031,
#   'pnl': 0.006087545869762785,
#   'entry_day': 3216,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.2116293811872625,
#   'exit_price': 8.684256032673566,
#   'pnl': 0.39806409876529003,
#   'entry_day': 3365,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.870524772826535,
#   'exit_price': 13.226589881173624,
#   'pnl': 0.046424695690997296,
#   'entry_day': 3437,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.583509053228591,
#   'exit_price': 11.59991267298853,
#   'pnl': 0.5296233698105763,
#   'entry_day': 3455,
#   'elapsed_day': 6},
#  {'type': 'short',
#   'entry_price': 13.145693643913669,
#   'exit_price': 10.741806969198613,
#   'pnl': 0.18286495485371607,
#   'entry_day': 3548,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.952762824016776,
#   'exit_price': 12.763751612601052,
#   'pnl': 0.08521690122683727,
#   'entry_day': 3696,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.096382534584885,
#   'exit_price': 8.379529887330403,
#   'pnl': 0.3601645442776456,
#   'entry_day': 3722,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.777424772083893,
#   'exit_price': 8.555967945251467,
#   'pnl': 0.48093108656183603,
#   'entry_day': 3786,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.57574727356279,
#   'exit_price': 6.477406970510578,
#   'pnl': 0.16171100530739185,
#   'entry_day': 3805,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.880597530980696,
#   'exit_price': 9.581862453252118,
#   'pnl': 0.6294028630206511,
#   'entry_day': 3822,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 12.449508080762737,
#   'exit_price': 8.07126654254281,
#   'pnl': 0.3516798824352976,
#   'entry_day': 3985,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.9773894826649325,
#   'exit_price': 9.555366141985212,
#   'pnl': 0.5985851632550956,
#   'entry_day': 4013,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.455180046613027,
#   'exit_price': 7.170878394054737,
#   'pnl': 0.11087194195570595,
#   'entry_day': 4035,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.916473058735829,
#   'exit_price': 4.725616010735605,
#   'pnl': -0.2012782000658133,
#   'entry_day': 4200,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 5.852447270594657,
#   'exit_price': 3.4125758806308006,
#   'pnl': -0.4168976288300578,
#   'entry_day': 4206,
#   'elapsed_day': 1},
#  {'type': 'long',
#   'entry_price': 7.650527519286285,
#   'exit_price': 4.354682464382975,
#   'pnl': -0.4307997123851635,
#   'entry_day': 4216,
#   'elapsed_day': 4},
#  {'type': 'long',
#   'entry_price': 5.763988593726378,
#   'exit_price': 10.040300432025113,
#   'pnl': 0.7419015094778544,
#   'entry_day': 4221,
#   'elapsed_day': 6},
#  {'type': 'long',
#   'entry_price': 5.560706763852106,
#   'exit_price': 8.70272015837264,
#   'pnl': 0.5650384974344425,
#   'entry_day': 4275,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.461204800137021,
#   'exit_price': 4.359070949608281,
#   'pnl': -0.3253470390667946,
#   'entry_day': 4303,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 5.595780490112048,
#   'exit_price': 6.607470380341545,
#   'pnl': 0.18079513519466864,
#   'entry_day': 4307,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.190905499361431,
#   'exit_price': 8.914197278445336,
#   'pnl': 0.4398858582746582,
#   'entry_day': 4354,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.966513319671323,
#   'exit_price': 7.230730122042199,
#   'pnl': 0.037926691624174114,
#   'entry_day': 4420,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.993651577844778,
#   'exit_price': 8.341199742957041,
#   'pnl': 0.39167244452277694,
#   'entry_day': 4435,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.837805510381802,
#   'exit_price': 11.25914667977485,
#   'pnl': 0.18634882739696812,
#   'entry_day': 4476,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.908876482905873,
#   'exit_price': 8.083368690285548,
#   'pnl': 0.36800434290180006,
#   'entry_day': 4503,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.077643783221585,
#   'exit_price': 9.31637321205034,
#   'pnl': 0.2876107220474148,
#   'entry_day': 4604,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.096233011491352,
#   'exit_price': 7.200687795875612,
#   'pnl': 0.014719751199701366,
#   'entry_day': 4643,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.782979075854266,
#   'exit_price': 9.82096171166748,
#   'pnl': 0.28745725741742245,
#   'entry_day': 4723,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 8.548144986081887,
#   'exit_price': 6.740827815030236,
#   'pnl': -0.2114279968337376,
#   'entry_day': 4784,
#   'elapsed_day': 4},
#  {'type': 'long',
#   'entry_price': 6.438828340803349,
#   'exit_price': 4.436450784531479,
#   'pnl': -0.31098477087557225,
#   'entry_day': 4800,
#   'elapsed_day': 5},
#  {'type': 'long',
#   'entry_price': 7.359962077572857,
#   'exit_price': 7.563657593100747,
#   'pnl': 0.02767616373304254,
#   'entry_day': 4808,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.83829864483478,
#   'exit_price': 9.670264672937412,
#   'pnl': 0.30119555003628345,
#   'entry_day': 4925,
#   'elapsed_day': 6},
#  {'type': 'short',
#   'entry_price': 13.181158604997002,
#   'exit_price': 9.772103410428942,
#   'pnl': 0.25863092135737453,
#   'entry_day': 4999,
#   'elapsed_day': 3},
#  {'type': 'short',
#   'entry_price': 13.183332996714132,
#   'exit_price': 11.697867376706915,
#   'pnl': 0.11267754674614229,
#   'entry_day': 5041,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.362085153490883,
#   'exit_price': 10.483690244527107,
#   'pnl': 0.4240110004101286,
#   'entry_day': 5259,
#   'elapsed_day': 5},
#  {'type': 'long',
#   'entry_price': 6.376871178949528,
#   'exit_price': 7.285862667724602,
#   'pnl': 0.14254506062090683,
#   'entry_day': 5350,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.30779572625544,
#   'exit_price': 6.43299612354782,
#   'pnl': -0.11970772521249344,
#   'entry_day': 5366,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.823862711848381,
#   'exit_price': 6.976282387759541,
#   'pnl': 0.022336275266281562,
#   'entry_day': 5422,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.919587563907537,
#   'exit_price': 12.19543674760432,
#   'pnl': 0.12386507921928755,
#   'entry_day': 5543,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.539219736614863,
#   'exit_price': 7.271727412530735,
#   'pnl': 0.3127710685430661,
#   'entry_day': 5844,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.211547319480729,
#   'exit_price': 5.6461095268873756,
#   'pnl': -0.2170737739409403,
#   'entry_day': 5861,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 6.343693286534741,
#   'exit_price': 6.589455925958089,
#   'pnl': 0.03874125502647001,
#   'entry_day': 5872,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.466613500518641,
#   'exit_price': 5.139512884297829,
#   'pnl': -0.20522343203507917,
#   'entry_day': 5881,
#   'elapsed_day': 3},
#  {'type': 'long',
#   'entry_price': 7.297827499965574,
#   'exit_price': 4.416020067632912,
#   'pnl': -0.39488566047173024,
#   'entry_day': 5885,
#   'elapsed_day': 3},
#  {'type': 'long',
#   'entry_price': 6.155693726184442,
#   'exit_price': 4.10665454060276,
#   'pnl': -0.33286893025000497,
#   'entry_day': 5891,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 6.63898662041413,
#   'exit_price': 6.537747489374706,
#   'pnl': -0.015249184375236643,
#   'entry_day': 5895,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.835925107213174,
#   'exit_price': 8.390114709170579,
#   'pnl': 0.2273561482289274,
#   'entry_day': 5908,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.361675595859394,
#   'exit_price': 11.88848718882456,
#   'pnl': 0.11025476531486487,
#   'entry_day': 5986,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.05424453561658,
#   'exit_price': 9.816985057701283,
#   'pnl': 0.30149322271838513,
#   'entry_day': 6023,
#   'elapsed_day': 5},
#  {'type': 'short',
#   'entry_price': 14.076550681631801,
#   'exit_price': 12.536193207865127,
#   'pnl': 0.10942719623612443,
#   'entry_day': 6066,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.106817191758527,
#   'exit_price': 5.943623806147686,
#   'pnl': -0.026723148980303334,
#   'entry_day': 6434,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.37105728084545,
#   'exit_price': 4.428531875421291,
#   'pnl': -0.3048984367577972,
#   'entry_day': 6443,
#   'elapsed_day': 5},
#  {'type': 'long',
#   'entry_price': 6.935148948530729,
#   'exit_price': 4.81227620546518,
#   'pnl': -0.3061034101531876,
#   'entry_day': 6451,
#   'elapsed_day': 3},
#  {'type': 'long',
#   'entry_price': 5.718599763456805,
#   'exit_price': 6.226779613668571,
#   'pnl': 0.08886438485503997,
#   'entry_day': 6459,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.701339774106021,
#   'exit_price': 5.720581515171176,
#   'pnl': -0.14635256411329794,
#   'entry_day': 6476,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.083197758797468,
#   'exit_price': 7.214152716230744,
#   'pnl': 0.18591454729508003,
#   'entry_day': 6548,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 12.592827614010016,
#   'exit_price': 9.519022329232566,
#   'pnl': 0.24409174642855594,
#   'entry_day': 6618,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 5.552542758441208,
#   'exit_price': 10.619839845078808,
#   'pnl': 0.9126083862990666,
#   'entry_day': 6706,
#   'elapsed_day': 5},
#  {'type': 'short',
#   'entry_price': 13.59259205748473,
#   'exit_price': 9.31164144662121,
#   'pnl': 0.3149473325439959,
#   'entry_day': 6739,
#   'elapsed_day': 3},
#  {'type': 'long',
#   'entry_price': 6.170171256430338,
#   'exit_price': 9.993401433529888,
#   'pnl': 0.6196311282470665,
#   'entry_day': 6757,
#   'elapsed_day': 5},
#  {'type': 'long',
#   'entry_price': 6.11568609517967,
#   'exit_price': 7.673774248226788,
#   'pnl': 0.2547691508030784,
#   'entry_day': 6820,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.580346375838895,
#   'exit_price': 11.624003718257235,
#   'pnl': 0.7664729262485594,
#   'entry_day': 6911,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.04028528354829,
#   'exit_price': 9.803791689948952,
#   'pnl': 0.24819193163530862,
#   'entry_day': 6979,
#   'elapsed_day': 5},
#  {'type': 'short',
#   'entry_price': 14.319013345555334,
#   'exit_price': 12.118573643764577,
#   'pnl': 0.1536725784583321,
#   'entry_day': 7016,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.28929923262228,
#   'exit_price': 9.487222576827776,
#   'pnl': 0.28610061292481476,
#   'entry_day': 7082,
#   'elapsed_day': 3},
#  {'type': 'long',
#   'entry_price': 6.274378365820897,
#   'exit_price': 10.187357642062583,
#   'pnl': 0.6236441362155148,
#   'entry_day': 7109,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.595045637648317,
#   'exit_price': 11.468345381057256,
#   'pnl': 0.15643200569343138,
#   'entry_day': 7265,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.962590297553739,
#   'exit_price': 5.36692261770222,
#   'pnl': -0.2291773049481522,
#   'entry_day': 7306,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.78026967328064,
#   'exit_price': 7.568381028257408,
#   'pnl': 0.11623598956285175,
#   'entry_day': 7315,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 12.408045282256968,
#   'exit_price': 11.202906283155205,
#   'pnl': 0.09712561259145837,
#   'entry_day': 7337,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.568110023535716,
#   'exit_price': 8.741413262729287,
#   'pnl': 0.35573832703551733,
#   'entry_day': 7367,
#   'elapsed_day': 6},
#  {'type': 'long',
#   'entry_price': 6.601793681742461,
#   'exit_price': 11.62808417511705,
#   'pnl': 0.7613522529907297,
#   'entry_day': 7439,
#   'elapsed_day': 2},
#  {'type': 'long',
#   'entry_price': 6.3557999213770735,
#   'exit_price': 10.496213347281707,
#   'pnl': 0.6514386036569185,
#   'entry_day': 7540,
#   'elapsed_day': 4},
#  {'type': 'long',
#   'entry_price': 5.810511624025663,
#   'exit_price': 9.988040479366635,
#   'pnl': 0.7189605882668691,
#   'entry_day': 7577,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.383681053430768,
#   'exit_price': 6.908674835271263,
#   'pnl': 0.08223997681687881,
#   'entry_day': 7614,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 7.092268233566493,
#   'exit_price': 9.782110780857659,
#   'pnl': 0.3792640744410372,
#   'entry_day': 7683,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 12.583752825833432,
#   'exit_price': 13.70941346367994,
#   'pnl': -0.0894534924061459,
#   'entry_day': 7767,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.109348043058706,
#   'exit_price': 13.924888712894303,
#   'pnl': -0.062210620021444875,
#   'entry_day': 7777,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.419671960901802,
#   'exit_price': 7.641377807986334,
#   'pnl': 0.19030658490420957,
#   'entry_day': 7859,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.42674341838009,
#   'exit_price': 11.348063985619964,
#   'pnl': 0.15481635181279976,
#   'entry_day': 7873,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.346112385357728,
#   'exit_price': 9.554489252508045,
#   'pnl': 0.5055657183999684,
#   'entry_day': 7902,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.073387793672683,
#   'exit_price': 11.511198280737874,
#   'pnl': 0.18205918507317445,
#   'entry_day': 7958,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.384848279785029,
#   'exit_price': 14.120260576599366,
#   'pnl': 0.018393499746360707,
#   'entry_day': 7996,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.945147350641482,
#   'exit_price': 14.269635940784589,
#   'pnl': -0.0232689251668739,
#   'entry_day': 8012,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 6.951089265928191,
#   'exit_price': 11.356046750691577,
#   'pnl': 0.6337075120520963,
#   'entry_day': 8031,
#   'elapsed_day': 4},
#  {'type': 'long',
#   'entry_price': 6.674480989813167,
#   'exit_price': 4.78876853575966,
#   'pnl': -0.2825257060334054,
#   'entry_day': 8107,
#   'elapsed_day': 5},
#  {'type': 'long',
#   'entry_price': 5.540165341085544,
#   'exit_price': 9.446082311372303,
#   'pnl': 0.7050181230730979,
#   'entry_day': 8119,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 14.04235437274776,
#   'exit_price': 9.2634558263131,
#   'pnl': 0.3403203209078066,
#   'entry_day': 8179,
#   'elapsed_day': 6},
#  {'type': 'short',
#   'entry_price': 11.296823332983072,
#   'exit_price': 9.72886686880956,
#   'pnl': 0.13879622774975922,
#   'entry_day': 8200,
#   'elapsed_day': 5},
#  {'type': 'long',
#   'entry_price': 6.893749165467157,
#   'exit_price': 11.044892027859866,
#   'pnl': 0.6021604155815562,
#   'entry_day': 8221,
#   'elapsed_day': 6},
#  {'type': 'short',
#   'entry_price': 13.741713314021176,
#   'exit_price': 12.546132270916269,
#   'pnl': 0.08700378299152928,
#   'entry_day': 8302,
#   'elapsed_day': 7},
#  {'type': 'short',
#   'entry_price': 13.277614761566337,
#   'exit_price': 12.581205984465026,
#   'pnl': 0.05244984054795374,
#   'entry_day': 8697,
#   'elapsed_day': 7},
#  {'type': 'long',
#   'entry_price': 5.753525444282332,
#   'exit_price': 7.478796811344038,
#   'pnl': 0.29986334183613034,
#   'entry_day': 8860,
#   'elapsed_day': 7}]

# %% [markdown]
# #4. 백테스트 코드

# %% [markdown]
# 백테스트를 실시하기 위해, 백테스트 함수를 짜 봅니다.

# %%
import matplotlib.pyplot as plt
# 포지션 가지구 백테스트
def backtest(positions):
    initial_capital = 1000000

    capital = initial_capital
    capital_history = [capital]

    for position in positions:
        if position['exit_price']:
            pnl = position['pnl']
            profit = capital * pnl
            capital += profit
            capital_history.append(capital)
    time_stamps = [i for i, _ in enumerate(capital_history)]

    # 그래프 초기화 및 그리기
    plt.figure(figsize=(14, 7))
    plt.plot(time_stamps, capital_history, label='Capital Over Time', color='blue', marker='o')

    plt.title('Portfolio Value Over Time')
    plt.xlabel('days')
    plt.ylabel('Portfolio Value')
    plt.legend()

    plt.show()

# %% [markdown]
# 포지션을 백테스트 함수에 넣어 plot을 확인해 봅시다.

# %%
backtest(positions)

# %% [markdown]
# # 5. 코스피 데이터로 똑같이 따라해보기!

# %% [markdown]
# 어떻게 사용하는지 헷갈릴까봐 코스피 데이터를 통해서 실행하는 예제입니다

# %%
data = pd.read_excel('/Users/hanjiwon/jupyter-tutorial/study/코스닥코스피.xlsx')['코스피']
data.name = 'price'
data
# Out:
# 0       1918.76
# 1       1930.53
# 2       1925.43
# 3       1904.33
# 4       1917.62
#          ...
# 2014    2497.09
# 2015    2497.09
# 2016    2497.09
# 2017    2497.09
# 2018    2497.09
# Name: price, Length: 2019, dtype: float64

# %% [markdown]
# 1) 데이터의 형태 plot으로 확인하기

# %%
#빈칸을 채워 보세요!
data.plot()
# Out:
# <Axes: >

# %% [markdown]
# 2) 시계열 데이터가 정상성을 갖는지 검정하기

# %%
#빈칸을 채워 보세요!
adftest(data)
# Out:
# 정상성이 있는지 판단 :
# ADF Statistic: -1.885626
# p-value: 0.338853
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# '10%'

# %% [markdown]
# 3) 시계열 데이터로 ARIMA 모델 fitting 하기

# %%
 #빈칸을 채워 보세요!
half = ARIMA_model(data)
# Out:
# λ 값의 유도(델타yt가 아닌 그냥 yt임 주의!!) : 0.997573917447784
# 반감기 : 285.7063457823488
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                 2019
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -9300.132
# Date:                Tue, 02 Apr 2024   AIC                          18606.264
# Time:                        20:33:21   BIC                          18623.095
# Sample:                             0   HQIC                         18612.441
#                                - 2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2389.0556    168.435     14.184      0.000    2058.930    2719.182
# ar.L1          0.9976      0.001    825.569      0.000       0.995       1.000
# sigma2       585.2687     11.538     50.726      0.000     562.655     607.882
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):               831.32
# Prob(Q):                              0.61   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.66   Skew:                            -0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# 4) Hurst 지수 검정하기

# %%
data = data.to_numpy() #데이터 형식 맞추기
#빈칸을 채워 보세요!
hurst_func(data)
# Out:
# 0.6239491790851018

# %% [markdown]
# 5) Position 만들고 확인하기

# %%
#빈칸을 채워 보세요!
positions = position(data,half)
positions
# Out:
# [{'type': 'long',
#   'entry_price': 1704.76,
#   'exit_price': 2418.67,
#   'pnl': 0.41877449025082714,
#   'entry_day': 1036,
#   'elapsed_day': 95},
#  {'type': 'short',
#   'entry_price': 3085.9,
#   'exit_price': 2659.23,
#   'pnl': 0.13826436371885029,
#   'entry_day': 1236,
#   'elapsed_day': 286}]

# %% [markdown]
# 6) 백테스트

# %%
import matplotlib.pyplot as plt
import numpy as np

def backtest(data, positions):
    initial_capital = 1000000
    capital = initial_capital
    capital_history = [initial_capital]
    sorted_positions = sorted(positions, key=lambda x: x['entry_day'])

    last_day = 0
    for position in sorted_positions:
        pnl = position['pnl']
        day = position['entry_day'] + position['elapsed_day']
        for _ in range(day - last_day - 1):
            capital_history.append(capital)

        capital += capital * pnl
        capital_history.append(capital)
        last_day = day

    for _ in range(len(data) - last_day - 1):
        capital_history.append(capital)
    plt.figure(figsize=(14, 7))
    plt.plot(range(len(data)), capital_history, label='Capital Over Time', color='blue', marker='o')
    plt.title('Portfolio Value Over Time')
    plt.xlabel('Day')
    plt.ylabel('Portfolio Value')
    plt.legend()
    plt.show()


data_length = 300
data_example = np.zeros(data_length)
backtest(data, positions)

# %% [markdown]
# 7) position 진입 시점과 종료 시점 확인하기

# %%
#포지션 진입 시점과 종료 시점 그래프
def when(data):
    overall_mean = np.mean(data)
    overall_std = np.std(data)
    overall_mean, overall_std
    df = pd.DataFrame(data, columns=['price'])
    df['mean'] = overall_mean
    df['std'] = overall_std
    df['upper'] = overall_mean + 2*overall_std
    df['lower'] = overall_mean - 2*overall_std

    plt.figure(figsize=(14, 7))
    plt.plot(df.index, df['price'], label='Price', color='blue', alpha=0.6)
    plt.axhline(y=overall_mean + 2*overall_std, color='red', linestyle='--', label='Upper Limit')
    plt.axhline(y=overall_mean - 2*overall_std, color='green', linestyle='--', label='Lower Limit')
    display(positions)

    for position in positions:
        entry_index = position['entry_day']
        if position['exit_price']:
            exit_index = position['entry_day'] + position['elapsed_day']
            if position['type'] == 'long':
                plt.axvline(x=entry_index, color='gold', linestyle='-', linewidth=0.5)
                plt.axvline(x=exit_index, color='black', linestyle='-', linewidth=0.5)
            else:
                plt.axvline(x=entry_index, color='magenta', linestyle='-', linewidth=0.5)
                plt.axvline(x=exit_index, color='black', linestyle='-', linewidth=0.5)

    plt.legend()
    plt.title('Total Return with Entry and Exit Points')
    plt.xlabel('day')
    plt.ylabel('Price')
    plt.show()

when(data)
# Out:
# [{'type': 'long',
#   'entry_price': 1704.76,
#   'exit_price': 2418.67,
#   'pnl': 0.41877449025082714,
#   'entry_day': 1036,
#   'elapsed_day': 95},
#  {'type': 'short',
#   'entry_price': 3085.9,
#   'exit_price': 2659.23,
#   'pnl': 0.13826436371885029,
#   'entry_day': 1236,
#   'elapsed_day': 286}]

# %% [markdown]
# 각자 데이터를 다운받아 5번의 과정에 맞게 실습을 진행하고,
# 백테스트 결과를 전송해 주세요.

# %% [markdown]
# # GBP vs XPF

# %%
gbp = pd.read_excel('/Users/hanjiwon/jupyter-tutorial/study/GBP_XPF.xlsx')['GBP']
gbp.name = 'price'
gbp.plot()
# Out:
# <Axes: >

# %%
xpf = pd.read_excel('/Users/hanjiwon/jupyter-tutorial/study/GBP_XPF.xlsx')['XPF']
xpf.name = 'price'
xpf.plot()
# Out:
# <Axes: >

# %%
adftest(gbp)
# Out:
# 정상성이 있는지 판단 :
# ADF Statistic: -2.433272
# p-value: 0.132565
# Critical Values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# '10%'

# %%
adftest(xpf)
# Out:
# 정상성이 있는지 판단 :
# ADF Statistic: -2.192052
# p-value: 0.209143
# Critical Values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# '10%'

# %%
half_gbp = ARIMA_model(gbp)
# Out:
# λ 값의 유도(델타yt가 아닌 그냥 yt임 주의!!) : 0.9942479690824189
# 반감기 : 120.5047730952443
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                 2150
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                8429.595
# Date:                Tue, 02 Apr 2024   AIC                         -16853.190
# Time:                        20:33:26   BIC                         -16836.171
# Sample:                             0   HQIC                        -16846.964
#                                - 2150
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7721      0.019     40.617      0.000       0.735       0.809
# ar.L1          0.9942      0.002    519.900      0.000       0.990       0.998
# sigma2      2.297e-05   2.57e-07     89.519      0.000    2.25e-05    2.35e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.74   Jarque-Bera (JB):             18222.41
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.04   Skew:                            -0.89
# Prob(H) (two-sided):                  0.59   Kurtosis:                        17.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
half_xpf = ARIMA_model(xpf)
# Out:
# λ 값의 유도(델타yt가 아닌 그냥 yt임 주의!!) : 0.9948193988702027
# 반감기 : 133.79667015342284
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                 2150
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1660.812
# Date:                Tue, 02 Apr 2024   AIC                           3327.624
# Time:                        20:33:27   BIC                           3344.644
# Sample:                             0   HQIC                          3333.851
#                                - 2150
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        106.9380      2.075     51.526      0.000     102.870     111.006
# ar.L1          0.9948      0.002    519.490      0.000       0.991       0.999
# sigma2         0.2739      0.006     49.207      0.000       0.263       0.285
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.47   Jarque-Bera (JB):               586.43
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.77   Skew:                             0.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
gbp = gbp.to_numpy() #데이터 형식 맞추기
hurst_func(gbp)
# Out:
# 0.5310315201315244

# %%
xpf = xpf.to_numpy() #데이터 형식 맞추기
hurst_func(xpf)
# Out:
# 0.5644008992303233

# %%
positions_gbp = position(gbp,half_gbp)
positions_gbp
# Out:
# [{'type': 'short',
#   'entry_price': 0.8538,
#   'exit_price': 0.7675,
#   'pnl': 0.10107753572265173,
#   'entry_day': 416,
#   'elapsed_day': 92},
#  {'type': 'short',
#   'entry_price': 0.8296,
#   'exit_price': 0.7613,
#   'pnl': 0.08232883317261334,
#   'entry_day': 1052,
#   'elapsed_day': 6}]

# %%
positions_xpf = position(xpf,half_xpf)
positions_xpf
# Out:
# [{'type': 'short',
#   'entry_price': 116.59,
#   'exit_price': 112.84,
#   'pnl': 0.032163993481430654,
#   'entry_day': 363,
#   'elapsed_day': 134},
#  {'type': 'long',
#   'entry_price': 96.08,
#   'exit_price': 99.805,
#   'pnl': 0.038769775187343966,
#   'entry_day': 1568,
#   'elapsed_day': 134}]

# %%
import matplotlib.pyplot as plt
import numpy as np

def backtest(data, positions):
    initial_capital = 1000000
    capital = initial_capital
    capital_history = [initial_capital]
    sorted_positions = sorted(positions, key=lambda x: x['entry_day'])

    last_day = 0
    for position in sorted_positions:
        pnl = position['pnl']
        day = position['entry_day'] + position['elapsed_day']
        for _ in range(day - last_day - 1):
            capital_history.append(capital)

        capital += capital * pnl
        capital_history.append(capital)
        last_day = day

    for _ in range(len(data) - last_day - 1):
        capital_history.append(capital)
    plt.figure(figsize=(14, 7))
    plt.plot(range(len(data)), capital_history, label='Capital Over Time', color='blue', marker='o')
    plt.title('Portfolio Value Over Time')
    plt.xlabel('Day')
    plt.ylabel('Portfolio Value')
    plt.legend()
    plt.show()


data_length_gbp = 300
data_example_gbp = np.zeros(data_length_gbp)
backtest(gbp, positions_gbp)

# %%
import matplotlib.pyplot as plt
import numpy as np

def backtest(data, positions):
    initial_capital = 1000000
    capital = initial_capital
    capital_history = [initial_capital]
    sorted_positions = sorted(positions, key=lambda x: x['entry_day'])

    last_day = 0
    for position in sorted_positions:
        pnl = position['pnl']
        day = position['entry_day'] + position['elapsed_day']
        for _ in range(day - last_day - 1):
            capital_history.append(capital)

        capital += capital * pnl
        capital_history.append(capital)
        last_day = day

    for _ in range(len(data) - last_day - 1):
        capital_history.append(capital)
    plt.figure(figsize=(14, 7))
    plt.plot(range(len(data)), capital_history, label='Capital Over Time', color='blue', marker='o')
    plt.title('Portfolio Value Over Time')
    plt.xlabel('Day')
    plt.ylabel('Portfolio Value')
    plt.legend()
    plt.show()


data_length_xpf = 300
data_example_xpf = np.zeros(data_length_xpf)
backtest(xpf, positions_xpf)

# %%
#포지션 진입 시점과 종료 시점 그래프
def when(data):
    overall_mean = np.mean(data)
    overall_std = np.std(data)
    overall_mean, overall_std
    df = pd.DataFrame(data, columns=['price'])
    df['mean'] = overall_mean
    df['std'] = overall_std
    df['upper'] = overall_mean + 2*overall_std
    df['lower'] = overall_mean - 2*overall_std

    plt.figure(figsize=(14, 7))
    plt.plot(df.index, df['price'], label='Price', color='blue', alpha=0.6)
    plt.axhline(y=overall_mean + 2*overall_std, color='red', linestyle='--', label='Upper Limit')
    plt.axhline(y=overall_mean - 2*overall_std, color='green', linestyle='--', label='Lower Limit')
    display(positions)

    for position in positions:
        entry_index = position['entry_day']
        if position['exit_price']:
            exit_index = position['entry_day'] + position['elapsed_day']
            if position['type'] == 'long':
                plt.axvline(x=entry_index, color='gold', linestyle='-', linewidth=0.5)
                plt.axvline(x=exit_index, color='black', linestyle='-', linewidth=0.5)
            else:
                plt.axvline(x=entry_index, color='magenta', linestyle='-', linewidth=0.5)
                plt.axvline(x=exit_index, color='black', linestyle='-', linewidth=0.5)

    plt.legend()
    plt.title('Total Return with Entry and Exit Points')
    plt.xlabel('day')
    plt.ylabel('Price')
    plt.show()

when(gbp)
# Out:
# [{'type': 'long',
#   'entry_price': 1704.76,
#   'exit_price': 2418.67,
#   'pnl': 0.41877449025082714,
#   'entry_day': 1036,
#   'elapsed_day': 95},
#  {'type': 'short',
#   'entry_price': 3085.9,
#   'exit_price': 2659.23,
#   'pnl': 0.13826436371885029,
#   'entry_day': 1236,
#   'elapsed_day': 286}]

# %%
#포지션 진입 시점과 종료 시점 그래프
def when(data):
    overall_mean = np.mean(data)
    overall_std = np.std(data)
    overall_mean, overall_std
    df = pd.DataFrame(data, columns=['price'])
    df['mean'] = overall_mean
    df['std'] = overall_std
    df['upper'] = overall_mean + 2*overall_std
    df['lower'] = overall_mean - 2*overall_std

    plt.figure(figsize=(14, 7))
    plt.plot(df.index, df['price'], label='Price', color='blue', alpha=0.6)
    plt.axhline(y=overall_mean + 2*overall_std, color='red', linestyle='--', label='Upper Limit')
    plt.axhline(y=overall_mean - 2*overall_std, color='green', linestyle='--', label='Lower Limit')
    display(positions)

    for position in positions:
        entry_index = position['entry_day']
        if position['exit_price']:
            exit_index = position['entry_day'] + position['elapsed_day']
            if position['type'] == 'long':
                plt.axvline(x=entry_index, color='gold', linestyle='-', linewidth=0.5)
                plt.axvline(x=exit_index, color='black', linestyle='-', linewidth=0.5)
            else:
                plt.axvline(x=entry_index, color='magenta', linestyle='-', linewidth=0.5)
                plt.axvline(x=exit_index, color='black', linestyle='-', linewidth=0.5)

    plt.legend()
    plt.title('Total Return with Entry and Exit Points')
    plt.xlabel('day')
    plt.ylabel('Price')
    plt.show()

when(xpf)
# Out:
# [{'type': 'long',
#   'entry_price': 1704.76,
#   'exit_price': 2418.67,
#   'pnl': 0.41877449025082714,
#   'entry_day': 1036,
#   'elapsed_day': 95},
#  {'type': 'short',
#   'entry_price': 3085.9,
#   'exit_price': 2659.23,
#   'pnl': 0.13826436371885029,
#   'entry_day': 1236,
#   'elapsed_day': 286}]
